# %% [raw]
# """Cassandra was invented or created by Facebook.
#  Netflix,Uber,Microsoft,ebay,instagram,macdonalds all company use this.
# feature----> scalibility,high availablity, decentralized,less latency,no sql database,elastic,fault tolerant"""

# %%
pip install cassandra-driver
# Out:
# ...
#      |████████████████████████████████| 4.1 MB 3.1 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cassandra

# %%
import pandas as pd

# %%
df=pd.read_csv(r"/Users/yogesh/Desktop/Yogesh_Study_Document/Ineuron/dataset/sample_test.csv")

# %%
df
# Out:
#        Name               Emailid    Address  Pin Code sirname
# 0    yogesh  yogesh.jsr@gmail.com  bangalore  560045.0   kumar
# 1     pooja       pooja@gmail.com  bangalore   56533.0    sahi
# 2  manharan    manharan@gmail.com     raipur  565767.0    sahu
# 3     malti       malti@gmail.com     raipur  343655.0    devi
# 4   nandini     nandini@gmail.com  hyderabad   45465.0  kumari
# 5    sanket      sanket@gmail.com   dhamtari       NaN    sahu
# 6    preeti      preeti@gmail.com     mumbai  565565.0  kumari

# %%
df=pd.read_csv("taxonomy.csv")

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df=pd.read_csv("taxonomy.csv",header=None)

# %%
df
# Out:
#                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
df=pd.read_csv("taxonomy.csv",names=["a","b","c","d"])

# %%
df
# Out:
#                a                             b          c  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
df=pd.read_csv("taxonomy.csv",names=["a","b","c","d","ubuih"])

# %%
df
# Out:
#                a                             b          c  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d  ubuih
# 0             parent_name    NaN
# 1                     NaN    NaN
# 2               Emergency    NaN
# 3               Emergency    NaN
# 4          Emergency Cash    NaN
# ..                    ...    ...
# ...

# %%
df=pd.read_csv("taxonomy.csv",names=["a","b","c"])

# %%
df
# Out:
#                                         a          b                     c
# taxonomy_id                          name  parent_id           parent_name
# 101                             Emergency        NaN                   NaN
# 101-01                  Disaster Response        101             Emergency
# 101-02                     Emergency Cash        101             Emergency
# 101-02-01               Help Pay for Food     101-02        Emergency Cash
# ...                                   ...        ...                   ...
# 111-01-07                Workplace Rights     111-01  Advocacy & Legal Aid
# 111-02                          Mediation        111                 Legal
# 111-03                             Notary        111                 Legal
# 111-04                     Representation        111                 Legal
# 111-05       Translation & Interpretation        111                 Legal
#
# [291 rows x 3 columns]

# %%
pd.read_csv("sample_test.csv")
# Out:
#        Name               Emailid    Address  Pin Code sirname
# 0    yogesh  yogesh.jsr@gmail.com  bangalore  560045.0   kumar
# 1     pooja       pooja@gmail.com  bangalore   56533.0    sahi
# 2  manharan    manharan@gmail.com     raipur  565767.0    sahu
# 3     malti       malti@gmail.com     raipur  343655.0    devi
# 4   nandini     nandini@gmail.com  hyderabad   45465.0  kumari
# 5    sanket      sanket@gmail.com   dhamtari       NaN    sahu
# 6    preeti      preeti@gmail.com     mumbai  565565.0  kumari

# %%
pd.read_csv("sample_test.csv")
# Out:
#               #Name#Emailid#Address#Pin Code#sirname
# 0  yogesh#yogesh.jsr@gmail.com#bangalore#560045#k...
# 1         pooja#pooja@gmail.com#bangalore#56533#sahi
# 2     manharan#manharan@gmail.com#raipur#565767#sahu
# 3           malti#malti@gmail.com#raipur#343655#devi
# 4   nandini#nandini@gmail.com#hyderabad#45465#kumari
# 5             sanket#sanket@gmail.com#dhamtari##sahu
# 6       preeti#preeti@gmail.com#mumbai#565565#kumari

# %%
pd.read_csv("sample_test.csv",sep='#')
# Out:
#   Unnamed: 0                  Name    Emailid   Address Pin Code  sirname
# 0     yogesh  yogesh.jsr@gmail.com  bangalore  560045.0    kumar      NaN
# 1      pooja       pooja@gmail.com  bangalore   56533.0     sahi      NaN
# 2   manharan    manharan@gmail.com     raipur  565767.0     sahu      NaN
# 3      malti       malti@gmail.com     raipur  343655.0     devi      NaN
# 4    nandini     nandini@gmail.com  hyderabad   45465.0   kumari      NaN
# 5     sanket      sanket@gmail.com   dhamtari       NaN     sahu      NaN
# 6     preeti      preeti@gmail.com     mumbai  565565.0   kumari      NaN

# %%
pd.read_csv("sample_test.csv",sep='#',skiprows=[1,3])
# Out:
#   Unnamed: 0               Name    Emailid   Address Pin Code  sirname
# 0      pooja    pooja@gmail.com  bangalore   56533.0     sahi      NaN
# 1      malti    malti@gmail.com     raipur  343655.0     devi      NaN
# 2    nandini  nandini@gmail.com  hyderabad   45465.0   kumari      NaN
# 3     sanket   sanket@gmail.com   dhamtari       NaN     sahu      NaN
# 4     preeti   preeti@gmail.com     mumbai  565565.0   kumari      NaN

# %%
df=pd.read_csv("services.csv")

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df['application_process']
# Out:
# 0                            Walk in or apply by phone.
# 1                    Apply by phone for an appointment.
# 2           Phone for information (403-4300 Ext. 4322).
# 3                                       Apply by phone.
# 4                                Phone for information.
# 5     Walk in or apply by phone for membership appli...
# 6     Apply by phone or be referred by a doctor, soc...
# 7                                       Apply by phone.
# 8     Walk in. Proof of residency in California requ...
# 9     Walk in. Proof of California residency to rece...
# 10    Walk in. Proof of California residency require...
# 11    Walk in or apply by phone, email or webpage re...
# 12    Walk in. Proof of California residency require...
# 13    Call for appointment. Referral from human serv...
# 14            Walk in or through other agency referral.
# 15    Walk in. Written application, identification r...
# 16                                Call for information.
# ...

# %%
a=df['application_process']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a=df['application_process'][0]

# %%
type(a)
# Out:
# str

# %%
a=df[['application_process']]

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
b=df[['application_process','name']]

# %%
b
# Out:
#                                   application_process  \
# 0                          Walk in or apply by phone.
# 1                  Apply by phone for an appointment.
# 2         Phone for information (403-4300 Ext. 4322).
# 3                                     Apply by phone.
# 4                              Phone for information.
# 5   Walk in or apply by phone for membership appli...
# 6   Apply by phone or be referred by a doctor, soc...
# 7                                     Apply by phone.
# 8   Walk in. Proof of residency in California requ...
# 9   Walk in. Proof of California residency to rece...
# 10  Walk in. Proof of California residency require...
# 11  Walk in or apply by phone, email or webpage re...
# 12  Walk in. Proof of California residency require...
# 13  Call for appointment. Referral from human serv...
# 14          Walk in or through other agency referral.
# 15  Walk in. Written application, identification r...
# ...

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
c=df[['name']]

# %%
type(c)
# Out:
# pandas.core.frame.DataFrame

# %%
df=pd.read_excel("/Users/yogesh/Desktop/Yogesh_Study_Document/Ineuron/dataset/LUSID Excel - Setting up your IBOR.xlsx")

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
df=pd.read_excel("/Users/yogesh/Desktop/Yogesh_Study_Document/Ineuron/dataset/LUSID Excel - Setting up your IBOR.xlsx",sheet_name="Run valuation")
# Out:
# /Users/yogesh/opt/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')

# %%
df=pd.ExcelFile("/Users/yogesh/Desktop/Yogesh_Study_Document/Ineuron/dataset/LUSID Excel - Setting up your IBOR.xlsx")

# %%
df.sheet_names
# Out:
# ['Datetime format',
#  'View scopes',
#  'View portfolios',
#  'View holdings',
#  'Run valuation',
#  'Use Recipes',
#  'View transactions',
#  'Perform a reconciliation',
#  'Upload transactions',
#  'Set holdings',
#  'Create portfolio',
#  'Create portfolio group',
#  'Inputs']

# %%
for i in df.sheet_names:
    pd.read_excel("/Users/yogesh/Desktop/Yogesh_Study_Document/Ineuron/dataset/LUSID Excel - Setting up your IBOR.xlsx",sheet_name=i)
# Out:
# /Users/yogesh/opt/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
i
# Out:
# 'Inputs'

# %%
pd.read_csv("https://github.com/datasciencedojo/datasets/blob/master/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-76-d848fff6b8d2> in <module>
# ----> 1 pd.read_csv("https://github.com/datasciencedojo/datasets/blob/master/titanic.csv")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_html("https://github.com/datasciencedojo/datasets/blob/master/titanic.csv")
# Out:
# [     Unnamed: 0  PassengerId  Survived  Pclass  \
#  0           NaN            1         0       3
#  1           NaN            2         1       1
#  2           NaN            3         1       3
#  3           NaN            4         1       1
#  4           NaN            5         0       3
#  ..          ...          ...       ...     ...
#  886         NaN          887         0       2
#  887         NaN          888         1       1
#  888         NaN          889         0       3
#  889         NaN          890         1       1
#  890         NaN          891         0       3
#
#                                                    Name     Sex   Age  SibSp  \
#  0                              Braund, Mr. Owen Harris    male  22.0      1
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#  2                               Heikkinen, Miss. Laina  female  26.0      0
# ...
