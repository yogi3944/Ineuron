# %%
try:
    import pymongo
    client = pymongo.MongoClient("mongodb://yogesh:yogesh@cluster0-shard-00-00.gqm2y.mongodb.net:27017,cluster0-shard-00-01.gqm2y.mongodb.net:27017,cluster0-shard-00-02.gqm2y.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-8u73o7-shard-0&authSource=admin&retryWrites=true&w=majority")
    db = client.test
    db
except Exception as e:
    print(e)

# %%
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.gqm2y.mongodb.net:27017', 'cluster0-shard-00-00.gqm2y.mongodb.net:27017', 'cluster0-shard-00-02.gqm2y.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-8u73o7-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'test')

# %%
try:
    coll=db["ineuron_Database"]
except Exception as e:
    print(e)

# %%
try:
    dict1={"name":"yogesh",
      "email":"yogeshkumar.jsr@gmail.com",
      "product":[1,2,3,4,5],
       "company":"yogi.ltd"
    }
except Exception as e:
    print(e)

# %%
try:
    dict2={"name":"pooja",
      "email":"poojakumari.jsr@gmail.com",
      "product":[1,2,3,4,5],
       "company":"pooja.ltd"
    }
except Exception as e:
    print(e)

# %%
try:
    coll.insert_one(dict1)
    coll.insert_one(dict2)
except Exception as e:
    print(e)

# %%
try:
    import pandas as pd
    df=pd.read_csv("ODI_data.csv")
    df_dict=df.to_dict('record')
    df_dict
except Exception as e:
    print(e)

# %%
df_dict
# Out:
# [{'Unnamed: 0': 0,
#   'Player': 'SR Tendulkar (INDIA)',
#   'Span': '1989-2012',
#   'Mat': 463,
#   'Inns': '452',
#   'NO': '41',
#   'Runs': '18426',
#   'HS': '200*',
#   'Ave': '44.83',
#   'BF': '21367',
#   'SR': '86.23',
#   '100': '49',
#   '50': '96',
#   '0': '20',
#   'Unnamed: 13': nan},
#  {'Unnamed: 0': 1,
#   'Player': 'KC Sangakkara (Asia/ICC/SL)',
#   'Span': '2000-2015',
#   'Mat': 404,
#   'Inns': '380',
#   'NO': '41',
#   'Runs': '14234',
#   'HS': '169',
#   'Ave': '41.98',
#   'BF': '18048',
#   'SR': '78.86',
#   '100': '25',
#   '50': '93',
#   '0': '15',
#   'Unnamed: 13': nan},
#  {'Unnamed: 0': 2,
#   'Player': 'RT Ponting (AUS/ICC)',
#   'Span': '1995-2012',
#   'Mat': 375,
#   'Inns': '365',
#   'NO': '39',
#   'Runs': '13704',
#   'HS': '164',
#   'Ave': '42.03',
#   'BF': '17046',
#   'SR': '80.39',
#   '100': '30',
#   '50': '82',
#   '0': '20',
#   'Unnamed: 13': nan},
#  {'Unnamed: 0': 3,
#   'Player': 'ST Jayasuriya (Asia/SL)',
# ...

# %%
try:
    coll.insert_many(df_dict)
except Exception as e:
    print(e)

# %%
coll.insert_many(df_dict)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-108-1ab4080934f4> in <module>
# ----> 1 coll.insert_many(df_dict)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     587         blk = _Bulk(self, ordered, bypass_document_validation)
#     588         blk.ops = [doc for doc in gen()]
# --> 589         blk.execute(write_concern, session=session)
#     590         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     591
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     446                 self.execute_no_results(sock_info, generator)
#     447         else:
# --> 448             return self.execute_command(generator, write_concern, session)
#
# ...
